# %%
import nltk
from nltk.book import *

# %%
frqDist = FreqDist(text6)
frqDist.plot(20, cumulative=True)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Cumulative Counts'>

# %%
words_longer_30 = [word for word in text5 if len(word) > 30]
print( len(words_longer_30), words_longer_30 )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24208\2743381207.py in <module>
#       1 words_longer_30 = [word for word in text5 if len(word) > 30]
# ----> 2 pprint.pprint( len(words_longer_30), words_longer_30 )
#
# NameError: name 'pprint' is not defined
